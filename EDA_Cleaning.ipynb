# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("ncr_ride_bookings.csv")

# %%
df.describe(include='all')
# Out:
#               Date      Time    Booking ID Booking Status   Customer ID  \
# count       150000    150000        150000         150000        150000
# unique         365     62910        148767              5        148788
# top     2024-11-16  17:44:57  "CNR7908610"      Completed  "CID6468528"
# freq           462        16             3          93000             3
# mean           NaN       NaN           NaN            NaN           NaN
# std            NaN       NaN           NaN            NaN           NaN
# min            NaN       NaN           NaN            NaN           NaN
# 25%            NaN       NaN           NaN            NaN           NaN
# 50%            NaN       NaN           NaN            NaN           NaN
# 75%            NaN       NaN           NaN            NaN           NaN
# max            NaN       NaN           NaN            NaN           NaN
#
#        Vehicle Type Pickup Location Drop Location       Avg VTAT  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                              10500
# Avg CTAT                              48000
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
df.head(20)
# Out:
#           Date      Time    Booking ID         Booking Status   Customer ID  \
# 0   2024-03-23  12:29:38  "CNR5884300"        No Driver Found  "CID1982111"
# 1   2024-11-29  18:01:39  "CNR1326809"             Incomplete  "CID4604802"
# 2   2024-08-23  08:56:10  "CNR8494506"              Completed  "CID9202816"
# 3   2024-10-21  17:17:25  "CNR8906825"              Completed  "CID2610914"
# 4   2024-09-16  22:08:00  "CNR1950162"              Completed  "CID9933542"
# 5   2024-02-06  09:44:56  "CNR4096693"              Completed  "CID4670564"
# 6   2024-06-17  15:45:58  "CNR2002539"              Completed  "CID6800553"
# 7   2024-03-19  17:37:37  "CNR6568000"              Completed  "CID8610436"
# 8   2024-09-14  12:49:09  "CNR4510807"        No Driver Found  "CID7873618"
# 9   2024-12-16  19:06:48  "CNR7721892"             Incomplete  "CID5214275"
# 10  2024-06-14  16:24:12  "CNR9070334"              Completed  "CID6680340"
# ...

# %%
df.duplicated(subset=("Customer ID")).sum()
# Out:
# np.int64(1212)

# %%
df['Booking ID'].value_counts()
# Out:
# Booking ID
# "CNR7908610"    3
# "CNR9603232"    3
# "CNR3648267"    3
# "CNR2726142"    3
# "CNR7199036"    3
#                ..
# "CNR6500631"    1
# "CNR2468611"    1
# "CNR6358306"    1
# "CNR3030099"    1
# "CNR3447390"    1
# Name: count, Length: 148767, dtype: int64

# %%
df.dtypes
# Out:
# Date                                     str
# Time                                     str
# Booking ID                               str
# Booking Status                           str
# Customer ID                              str
# Vehicle Type                             str
# Pickup Location                          str
# Drop Location                            str
# Avg VTAT                             float64
# Avg CTAT                             float64
# Cancelled Rides by Customer          float64
# Reason for cancelling by Customer        str
# Cancelled Rides by Driver            float64
# Driver Cancellation Reason               str
# Incomplete Rides                     float64
# Incomplete Rides Reason                  str
# Booking Value                        float64
# Ride Distance                        float64
# Driver Ratings                       float64
# Customer Rating                      float64
# Payment Method                           str
# ...

# %%
df['Date']=pd.to_datetime(df['Date'],errors='coerce',format='mixed')

# %%
df.dtypes
# Out:
# Date                                 datetime64[us]
# Time                                         object
# Booking ID                                      str
# Booking Status                                  str
# Customer ID                                     str
# Vehicle Type                                    str
# Pickup Location                                 str
# Drop Location                                   str
# Avg VTAT                                    float64
# Avg CTAT                                    float64
# Cancelled Rides by Customer                 float64
# Reason for cancelling by Customer               str
# Cancelled Rides by Driver                   float64
# Driver Cancellation Reason                      str
# Incomplete Rides                            float64
# Incomplete Rides Reason                         str
# Booking Value                               float64
# Ride Distance                               float64
# ...

# %%
df['Time']=pd.to_datetime(df['Time'],errors='coerce',format='mixed').dt.time

# %%
df
# Out:
#              Date      Time    Booking ID   Booking Status   Customer ID  \
# 0      2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1      2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2      2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3      2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4      2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...           ...       ...           ...              ...           ...
# 149995 2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996 2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997 2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998 2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999 2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
df['Avg VTAT'] = df['Avg VTAT'].fillna(df['Avg VTAT'].median())

df['Avg CTAT'] = df['Avg CTAT'].fillna(df['Avg CTAT'].median())

df['Booking Value'] = df['Booking Value'].fillna(df['Booking Value'].median())

df['Ride Distance'] = df['Ride Distance'].fillna(df['Ride Distance'].median())

df['Driver Ratings'] = df['Driver Ratings'].fillna(df['Driver Ratings'].median())

df['Customer Rating'] = df['Customer Rating'].fillna(df['Customer Rating'].median())

# %%
df.isnull().sum()
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                                  0
# Avg CTAT                                  0
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                             0
# Ride Distance                             0
# Driver Ratings                            0
# Customer Rating                           0
# Payment Method                        48000
# dtype: int64

# %%
df['Booking Status'].value_counts()
# Out:
# Booking Status
# Completed                93000
# Cancelled by Driver      27000
# No Driver Found          10500
# Cancelled by Customer    10500
# Incomplete                9000
# Name: count, dtype: int64

# %%
df['Cancelled Rides by Customer'] = df['Cancelled Rides by Customer'].fillna(0)

# %%
df['Cancelled Rides by Driver'] = df['Cancelled Rides by Driver'].fillna(0)

# %%
df['Incomplete Rides'] = df['Incomplete Rides'].fillna(0)

# %%
df['Reason for cancelling by Customer'] = (
    df['Reason for cancelling by Customer'].fillna('Not Applicable')
)

df['Driver Cancellation Reason'] = (
    df['Driver Cancellation Reason'].fillna('Not Applicable')
)

df['Incomplete Rides Reason'] = (
    df['Incomplete Rides Reason'].fillna('Not Applicable')
)

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# UPI            45909
# Cash           25367
# Uber Wallet    12276
# Credit Card    10209
# Debit Card      8239
# Name: count, dtype: int64

# %%
# df['Payment Method'] = df['Payment Method'].fillna(
#     df['Payment Method'].mode()[0]
# )

# %%
pd.crosstab(df['Booking Status'], df['Payment Method'].isna())
# Out:
# Payment Method         False
# Booking Status
# Cancelled by Customer  10500
# Cancelled by Driver    27000
# Completed              93000
# Incomplete              9000
# No Driver Found        10500

# %%
pd.crosstab(df['Booking Status'], df['Payment Method'].isna())
# Out:
# Payment Method         False
# Booking Status
# Cancelled by Customer  10500
# Cancelled by Driver    27000
# Completed              93000
# Incomplete              9000
# No Driver Found        10500

# %%
df.groupby('Booking Status')['Payment Method'].apply(lambda x: x.isna().sum())
# Out:
# Booking Status
# Cancelled by Customer    0
# Cancelled by Driver      0
# Completed                0
# Incomplete               0
# No Driver Found          0
# Name: Payment Method, dtype: int64

# %%
df['Payment Method'].value_counts(dropna=False)
# Out:
# Payment Method
# UPI            93909
# Cash           25367
# Uber Wallet    12276
# Credit Card    10209
# Debit Card      8239
# Name: count, dtype: int64

# %%
# Numerical columns
df['Avg VTAT'] = df['Avg VTAT'].fillna(df['Avg VTAT'].median())
df['Avg CTAT'] = df['Avg CTAT'].fillna(df['Avg CTAT'].median())
df['Booking Value'] = df['Booking Value'].fillna(df['Booking Value'].median())
df['Ride Distance'] = df['Ride Distance'].fillna(df['Ride Distance'].median())
df['Driver Ratings'] = df['Driver Ratings'].fillna(df['Driver Ratings'].median())
df['Customer Rating'] = df['Customer Rating'].fillna(df['Customer Rating'].median())

# Indicator columns
df['Cancelled Rides by Customer'] = df['Cancelled Rides by Customer'].fillna(0)
df['Cancelled Rides by Driver'] = df['Cancelled Rides by Driver'].fillna(0)
df['Incomplete Rides'] = df['Incomplete Rides'].fillna(0)

# Reason
df['Reason for cancelling by Customer'] = df['Reason for cancelling by Customer'].fillna('Not Applicable')
df['Driver Cancellation Reason'] = df['Driver Cancellation Reason'].fillna('Not Applicable')
df['Incomplete Rides Reason'] = df['Incomplete Rides Reason'].fillna('Not Applicable')

# %%
df.isnull().sum()
# Out:
# Date                                 0
# Time                                 0
# Booking ID                           0
# Booking Status                       0
# Customer ID                          0
# Vehicle Type                         0
# Pickup Location                      0
# Drop Location                        0
# Avg VTAT                             0
# Avg CTAT                             0
# Cancelled Rides by Customer          0
# Reason for cancelling by Customer    0
# Cancelled Rides by Driver            0
# Driver Cancellation Reason           0
# Incomplete Rides                     0
# Incomplete Rides Reason              0
# Booking Value                        0
# Ride Distance                        0
# Driver Ratings                       0
# Customer Rating                      0
# Payment Method                       0
# dtype: int64

# %%
df.duplicated(subset=['Booking ID', 'Customer ID']).sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                              Date       Avg VTAT       Avg CTAT  \
# count                      150000  150000.000000  150000.000000
# mean   2024-06-30 16:42:40.320000       8.445407      29.037753
# min           2024-01-01 00:00:00       2.000000      10.000000
# 25%           2024-03-31 00:00:00       5.600000      25.000000
# 50%           2024-07-01 00:00:00       8.300000      28.800000
# 75%           2024-09-30 00:00:00      11.000000      32.900000
# max           2024-12-30 00:00:00      20.000000      45.000000
# std                           NaN       3.639311       7.343053
#
#        Cancelled Rides by Customer  Cancelled Rides by Driver  \
# count                150000.000000              150000.000000
# mean                      0.070000                   0.180000
# min                       0.000000                   0.000000
# 25%                       0.000000                   0.000000
# 50%                       0.000000                   0.000000
# ...

# %%
Q1 = df['Booking Value'].quantile(0.25)
Q3 = df['Booking Value'].quantile(0.75)
IQR = Q3 - Q1

upper_limit = Q3 + 1.5 * IQR

booking_outliers = df[df['Booking Value'] > upper_limit]

booking_outliers
# Out:
#              Date      Time    Booking ID Booking Status   Customer ID  \
# 14     2024-10-18  18:28:53  "CNR8962232"      Completed  "CID1789354"
# 29     2024-11-03  12:24:59  "CNR8779845"      Completed  "CID7444351"
# 42     2024-02-12  19:42:39  "CNR4130953"     Incomplete  "CID3196782"
# 50     2024-05-04  21:26:59  "CNR1572483"     Incomplete  "CID6059557"
# 80     2024-02-10  09:17:39  "CNR4487090"      Completed  "CID1210782"
# ...           ...       ...           ...            ...           ...
# 149960 2024-08-10  16:19:57  "CNR3992344"      Completed  "CID2988625"
# 149966 2024-08-03  12:37:00  "CNR2520587"      Completed  "CID5647520"
# 149984 2024-01-14  15:42:15  "CNR2761999"     Incomplete  "CID3743304"
# 149996 2024-11-24  15:55:09  "CNR2468611"      Completed  "CID2325623"
# 149997 2024-09-18  10:55:15  "CNR6358306"      Completed  "CID9925486"
#
#          Vehicle Type         Pickup Location        Drop Location  Avg VTAT  \
# ...

# %%
df.nlargest(20, 'Booking Value')[
    ['Booking ID', 'Booking Status', 'Vehicle Type',
     'Ride Distance', 'Booking Value']
]
# Out:
#           Booking ID Booking Status   Vehicle Type  Ride Distance  \
# 7450    "CNR7954315"      Completed        Go Mini           8.66
# 83506   "CNR1798489"      Completed           Bike          11.73
# 2731    "CNR8487909"      Completed           Auto          10.11
# 90418   "CNR5182516"      Completed           Auto           4.62
# 7116    "CNR7356012"      Completed        Go Mini          25.66
# 43469   "CNR8849175"      Completed        Go Mini          36.81
# 21011   "CNR5553074"      Completed          eBike          20.85
# 32935   "CNR8715944"      Completed       Go Sedan          46.36
# 117985  "CNR7652202"      Completed           Auto          42.72
# 90667   "CNR8875064"      Completed       Go Sedan           4.97
# 10040   "CNR1017046"      Completed           Auto          32.11
# 148435  "CNR7877701"      Completed        Go Mini          47.39
# 70536   "CNR5928940"      Completed  Premier Sedan          18.02
# ...

# %%
df['Booking Value per KM'] = df['Booking Value'] / df['Ride Distance']

df.nlargest(20, 'Booking Value per KM')[
    ['Booking ID', 'Booking Status', 'Vehicle Type',
     'Ride Distance', 'Booking Value', 'Booking Value per KM']
]
# Out:
#           Booking ID Booking Status   Vehicle Type  Ride Distance  \
# 24759   "CNR3705367"     Incomplete  Premier Sedan           1.00
# 51750   "CNR8682875"     Incomplete        Go Mini           1.41
# 121945  "CNR3303271"      Completed  Premier Sedan           2.06
# 100563  "CNR9120177"      Completed       Go Sedan           2.31
# 127717  "CNR1834127"     Incomplete  Premier Sedan           1.29
# 86947   "CNR4939487"      Completed           Bike           2.38
# 38945   "CNR7942625"      Completed           Auto           2.35
# 13504   "CNR3283452"     Incomplete       Go Sedan           2.69
# 132831  "CNR8210349"     Incomplete        Uber XL           1.01
# 78576   "CNR2137752"     Incomplete           Auto           2.69
# 90255   "CNR9755722"      Completed        Go Mini           2.29
# 52699   "CNR4880201"     Incomplete           Auto           1.16
# 96408   "CNR7196458"     Incomplete           Bike           1.23
# ...

# %%
df.groupby('Vehicle Type')['Booking Value'].agg(
    ['count', 'mean', 'median', 'min', 'max']
)
# Out:
#                count        mean  median   min     max
# Vehicle Type
# Auto           37419  476.979021   414.0  50.0  4220.0
# Bike           22517  479.631700   414.0  50.0  4228.0
# Go Mini        29806  478.007247   414.0  50.0  4277.0
# Go Sedan       27141  479.806971   414.0  50.0  4088.0
# Premier Sedan  18111  478.983822   414.0  50.0  4008.0
# Uber XL         4449  474.103844   414.0  50.0  3703.0
# eBike          10557  475.149095   414.0  50.0  4093.0

# %%
df.groupby('Vehicle Type')['Booking Value per KM'].agg(
    ['count', 'mean', 'median', 'min', 'max']
)
# Out:
#                count       mean     median       min          max
# Vehicle Type
# Auto           37419  31.466556  17.453626  1.020616  1483.829787
# Bike           22517  31.586334  17.453626  1.018123  1582.773109
# Go Mini        29806  31.247325  17.453626  1.008065  2170.212766
# Go Sedan       27141  31.469858  17.453626  1.025220  1659.740260
# Premier Sedan  18111  31.326574  17.453626  1.036055  3148.000000
# Uber XL         4449  31.469508  17.453626  1.113445  1311.881188
# eBike          10557  30.283261  17.453626  1.022659   943.529412

# %%
df['Booking Value'].nunique()
# Out:
# 2566

# %%
df[df['Booking Value per KM'] > 500].shape
# Out:
# (278, 22)

# %%
df[df['Booking Value per KM'] > 1000].shape
# Out:
# (22, 22)

# %%
df[df['Booking Value per KM'] > 500][
    ['Booking ID', 'Booking Status', 'Vehicle Type',
     'Ride Distance', 'Booking Value', 'Booking Value per KM']
].sort_values('Booking Value per KM', ascending=False)
# Out:
#           Booking ID Booking Status   Vehicle Type  Ride Distance  \
# 24759   "CNR3705367"     Incomplete  Premier Sedan           1.00
# 51750   "CNR8682875"     Incomplete        Go Mini           1.41
# 121945  "CNR3303271"      Completed  Premier Sedan           2.06
# 100563  "CNR9120177"      Completed       Go Sedan           2.31
# 127717  "CNR1834127"     Incomplete  Premier Sedan           1.29
# ...              ...            ...            ...            ...
# 43876   "CNR1719332"      Completed  Premier Sedan           2.27
# 60266   "CNR9302969"      Completed           Bike           3.92
# 101002  "CNR6163713"      Completed       Go Sedan           3.18
# 138333  "CNR2052805"      Completed           Bike           3.18
# 61866   "CNR6137514"     Incomplete       Go Sedan           1.65
#
#         Booking Value  Booking Value per KM
# 24759          3148.0           3148.000000
# 51750          3060.0           2170.212766
# ...
